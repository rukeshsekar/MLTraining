# %%
#%reset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mkt = pd.read_csv("D:/dat1/retailMarketing29jun.csv",sep = ',')
mkt.head()
mkt.shape
# Out:
# (250, 12)

# %%
mkt.head()
# Out:
#    Customer  Age  Gender  Own Home  Married  Close    Salary  Children  \
# 0         1   73       0         0        0      1   16400.0         1
# 1         2   22       0         1        1      0  108100.0         3
# 2         3   51       1         1        1      1   97300.0         1
# 3         4   48       1         1        1      1   26800.0         0
# 4         5   57       1         0        0      1   11200.0         0
#
#    PrevCust  PrevSpent  Catalogs  AmountSpent
# 0         1      246.0        12        218.0
# 1         1     1622.0        18       2632.0
# 2         0        0.0        12       3048.0
# 3         1      536.0        12        435.0
# 4         0        0.0         6        106.0

# %% [markdown]
# %matplotlib inline

# %%
#mkt['Salary'] = pd.to_numeric(mkt.Salary.str.replace(r'[$,]',''))
mkt['AmountSpent'] = pd.to_numeric(mkt.AmountSpent.str.replace(r'[$,]',''))
mkt['PrevSpent'] = pd.to_numeric(mkt.PrevSpent.str.replace(r'[$,]',''))

# %%
mkt.dtypes
# Out:
# Customer         int64
# Age              int64
# Gender           int64
# Own Home         int64
# Married          int64
# Close            int64
# Salary         float64
# Children         int64
# PrevCust         int64
# PrevSpent      float64
# Catalogs         int64
# AmountSpent    float64
# dtype: object

# %%
# plot(y,x)
plt.plot(mkt.AmountSpent,mkt.Salary)
plt.xlabel('Salary')
plt.ylabel('Amount Spent')
plt.title('Amount Spent by different Salary bucket')
plt.show()

# %%
# plot(y,x)
plt.plot(mkt.AmountSpent,mkt.Salary)
plt.ylabel('Salary')
plt.xlabel('Amount Spent')
plt.title('Amount Spent by different Salary bucket')
plt.show()

# %%
# 1 is the no. of rows, 2 is the no. of columhns, plot no.
plt.subplot(2,2,1)
plt.plot(mkt.AmountSpent,mkt.Salary,'g')
plt.subplot(2,2,2)
plt.plot(mkt.Salary,mkt.AmountSpent)
plt.subplot(2,2,3)
plt.plot(mkt.AmountSpent, mkt.Children)

# %%
plt.hist(mkt.AmountSpent)
# Out:
# (array([ 356.,  261.,  181.,   95.,   65.,   24.,    8.,    2.,    5.,    3.]),
#  array([   38. ,   655.9,  1273.8,  1891.7,  2509.6,  3127.5,  3745.4,
#          4363.3,  4981.2,  5599.1,  6217. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(mkt.AmountSpent,bins=5)

# %%
sns.distplot(mkt.AmountSpent,kde=False,bins=5)  # kernel density estimation

# %%
sns.jointplot(mkt.AmountSpent,mkt.Salary)

# %%
sns.jointplot(mkt.AmountSpent,mkt.Salary,kind='hex')

# %%
sns.jointplot(mkt.AmountSpent,mkt.Salary,kind='reg')

# %%
sns.jointplot(mkt.AmountSpent,mkt.Salary,kind='kde')

# %%
sns.violinplot(mkt.Children,mkt.AmountSpent)
# Out:
# C:\Users\home\Anaconda2\lib\site-packages\seaborn\categorical.py:598: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# C:\Users\home\Anaconda2\lib\site-packages\seaborn\categorical.py:826: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
sns.pairplot(mkt)

# %%
sns.countplot(x='Children',hue='Age',data=mkt)
sns.plt.show()
# Out:
# C:\Users\home\Anaconda2\lib\site-packages\seaborn\categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-67a7cdc0b2d4> in <module>()
#       1 sns.countplot(x='Children',hue='Age',data=mkt)
# ----> 2 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
sns.countplot(x='Children',data=mkt)
sns.plt.show()
# Out:
# C:\Users\home\Anaconda2\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-60e734624b7c> in <module>()
#       1 sns.countplot(x='Children',data=mkt)
# ----> 2 sns.plt.show()
#
# AttributeError: 'module' object has no attribute 'plt'

# %%
sns.barplot(x='Age',y='AmountSpent',hue='Married', data=mkt)

# %%
# select avg(Salaru) group by Age
x= mkt.groupby(['Age'])['Salary'].mean()
x
# Out:
# Age
# Middle    72036.417323
# Old       56365.853659
# Young     27715.679443
# Name: Salary, dtype: float64

# %%
x.dtypes
# Out:
# dtype('float64')

# %%
sns.boxplot(x='OwnHome',y='Salary',hue='Married',data=mkt)
# Out:
# C:\Users\home\Anaconda2\lib\site-packages\seaborn\categorical.py:490: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])

# %%
sns.boxplot(x='Catalogs',y='AmountSpent',data=mkt)
# Out:
# C:\Users\home\Anaconda2\lib\site-packages\seaborn\categorical.py:462: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
a1 = 10,23,44,55
type(a1)
# Out:
# tuple

# %%
np.arange()
