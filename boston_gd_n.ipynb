# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv(r'D:\FinalMaterials\GradientDescent-BostonHouse-master\train_boston_gd.csv',delimiter = ',')
test_data = pd.read_csv(r'D:\FinalMaterials\GradientDescent-BostonHouse-master\test_boston_gd.csv',delimiter = ',')
train_data.isnull().sum()
# Out:
# # CRIM      0
#  ZN         0
#  INDUS      0
#  CHAS       0
#  NOX        0
#  RM         0
#  AGE        0
#  DIS        0
#  RAD        0
#  TAX        0
#  PTRATIO    0
#  B          0
#  LSTAT      0
#  Y          0
# dtype: int64

# %%
# y_train = train_data.iloc[:,13:14]
Y = train_data[' Y']
del train_data[' Y']

# %%
last = np.zeros(train_data.shape[0])
train_data['last'] = last
train_data
# Out:
#        # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# 5   -0.416934  1.014463 -1.403178 -0.272599 -0.973497  1.362495 -0.685427
# 6   -0.002920 -0.487722  1.015999 -0.272599  0.218592  0.217069  0.228480
# 7   -0.225559 -0.487722  1.231945 -0.272599  2.732346 -0.231698  1.021481
# 8   -0.395561  0.456508 -0.769931 -0.272599 -1.068519 -0.083534  0.377835
# 9   -0.413779  2.945843 -1.403178 -0.272599 -1.301754  1.428029 -1.225947
# 10  -0.397305 -0.487722 -0.548149 -0.272599 -0.532942  0.130165 -0.507624
# 11  -0.406627 -0.487722  0.247057 -0.272599 -1.016689 -0.008027  0.210700
# ...

# %%
points = np.array(train_data)
points.shape
# Out:
# (379, 14)

# %%
def step_gradient(points, learning_rate, m):
    m_slope = np.zeros(14)
    M = len(points)
    for i in range(M):
        x = points[i]
        y = Y[i]
        for j in range(14):
            m_slope[j] = m_slope[j]+(-2/M)* (y - (m * x).sum() )*x[j]
            
    for j in range(14):
        m[j] = m[j] - learning_rate*m_slope[j]
    
    return m

# %%
def gd(points, learning_rate, num_iterations):
    m=np.zeros(14)
    for i in range(num_iterations):
        m = step_gradient(points, learning_rate, m)
        print(i, " Cost: ", cost(points, m))
    return m

# %%
def cost(points, m):
    total_cost = 0
    M = len(points)
    for i in range(M):
        x = points[i]
        y = Y[i]
        total_cost += (1/M)*((y - (m*x).sum() )**2)
    return total_cost

# %%
def run():
    learning_rate = 0.001
    num_iterations = 1000
    m = gd(points, learning_rate, num_iterations)
    print(m)
    return m

# %%
m = run()
# Out:
# 0  Cost:  598.3388966495456
# 1  Cost:  597.5709116510045
# 2  Cost:  596.8179538126806
# 3  Cost:  596.0796716160776
# 4  Cost:  595.3557221281584
# 5  Cost:  594.6457707896772
# 6  Cost:  593.9494912087463
# 7  Cost:  593.2665649594985
# 8  Cost:  592.5966813857185
# 9  Cost:  591.9395374093383
# 10  Cost:  591.29483734365
# 11  Cost:  590.6622927111356
# 12  Cost:  590.0416220658061
# 13  Cost:  589.4325508199164
# 14  Cost:  588.8348110749673
# 15  Cost:  588.2481414568826
# 16  Cost:  587.6722869552522
# 17  Cost:  587.1069987665547
# 18  Cost:  586.5520341412413
# 19  Cost:  586.0071562346066
# 20  Cost:  585.4721339613354
# 21  Cost:  584.9467418536489
# 22  Cost:  584.4307599229473
# 23  Cost:  583.9239735248764
# 24  Cost:  583.4261732277198
# 25  Cost:  582.9371546840516
# 26  Cost:  582.456718505542
# 27  Cost:  581.9846701408767
# 28  Cost:  581.5208197566722
# 29  Cost:  581.0649821213417
# 30  Cost:  580.6169764918301
# 31  Cost:  580.1766265031348
# ...

# %%
m

# %%
test_data[1] = np.ones(test_data.shape[0])

# %%
y_test = []
x1=np.array(test_data)
M = x1.shape[0]
for i in range(M):
    x = x1[i]
    z=(m*x).sum()
    y_test.append(z)

# %%
add_row=test_data.columns
add_row
row=[]
for i in add_row:
    row.append(float(i))
row=np.array(row)
z=(row*m).sum()
z
# Out:
# 38.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-904686b42354> in <module>()
#       5     row.append(float(i))
#       6 row=np.array(row)
# ----> 7 z=(row*m).sum()
#       8 z
#
# ValueError: operands could not be broadcast together with shapes (13,) (14,)

# %%
y_test.insert(0,z)

# %%
y_test=np.array(y_test)

# %%
np.savetxt('result_boston_new.csv', y_test, delimiter=',',fmt='%1.5f')
