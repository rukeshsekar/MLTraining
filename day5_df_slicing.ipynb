# %%
import numpy as np
import pandas as pd
from pandas import Series

# %%
df = pd.read_csv("D:/dat1/SalesJan2009.csv", delimiter=',')

# %%
df.head()
# Out:
#   Transaction_date   Product Price Payment_Type               Name  \
# 0    1/2/2009 6:17  Product1  1200   Mastercard           carolina
# 1    1/2/2009 4:53  Product1  1200         Visa             Betina
# 2   1/2/2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3   1/3/2009 14:44  Product1  1200         Visa              Gouya
# 4   1/4/2009 12:56  Product2  3600         Visa            Gerd W
#
#                            City     State         Country   Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/2009 6:00
# 1  Parkville                           MO   United States     1/2/2009 4:42
# 2  Astoria                             OR   United States    1/1/2009 16:21
# 3                        Echuca  Victoria       Australia   9/25/2005 21:13
# 4  Cahaba Heights                      AL   United States  11/15/2008 15:47
#
#        Last_Login   Latitude   Longitude
# 0   1/2/2009 6:08  51.500000   -1.116667
# ...

# %%
sdf = pd.Series([2,4.23,50,60])

# %%
sdf
# Out:
# 0     2.00
# 1     4.23
# 2    50.00
# 3    60.00
# dtype: float64

# %%
l = [2,4,5,6]
l
# Out:
# [2, 4, 5, 6]

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 2)
# (1, 4)
# (2, 5)
# (3, 6)

# %%
sdf[sdf > 20]
# Out:
# 2    50.0
# 3    60.0
# dtype: float64

# %%
sdf
# Out:
# 0     2.00
# 1     4.23
# 2    50.00
# 3    60.00
# dtype: float64

# %%
sdf = pd.Series([2,4.23,50,60], index=['row1','row2','row3','row4' ])
sdf
# Out:
# row1     2.00
# row2     4.23
# row3    50.00
# row4    60.00
# dtype: float64

# %%
sdf[3]
# Out:
# 'Senthil'

# %%
type(sdf)
# Out:
# pandas.core.series.Series

# %%
l
# Out:
# [2, 4, 5, 6]

# %%
j = 4
count=0
for i in l:
    if i > j:
        print(i)
        count = count + 1
# Out:
# 5
# 6

# %%
sdf[sdf > 29]
# Out:
# 2    50.0
# 3    60.0
# dtype: float64

# %%
sdf.shape
# Out:
# (4,)

# %%
sdf
# Out:
# 0     2.00
# 1     4.23
# 2    50.00
# 3    60.00
# dtype: float64

# %%
sdf.size
# Out:
# 4

# %%
df = pd.read_csv("D:/dat1/warranty.csv", sep=',')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape   #rows, columns
# Out:
# (26, 26)

# %%
df
# Out:
#     Row ID      Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0    41520  MA-2013-1850  10/14/2013  10/15/2013     First Class     DH-3675
# 1    47596  CG-2012-2700  12/22/2012  12/24/2012    Second Class     DH-3675
# 2    45892   EG-2014-710    9/3/2014    9/9/2014  Standard Class     DH-3675
# 3    48904  AU-2014-6170   2/17/2014   2/20/2014    Second Class     DH-3675
# 4    42850  TU-2013-3950    4/5/2013    4/6/2013     First Class     DH-3675
# 5    42855  TU-2013-3950    4/5/2013    4/6/2013     First Class     DH-3675
# 6    42655  AG-2011-1390   8/16/2011   8/21/2011  Standard Class     DH-3675
# 7    43582  RS-2011-8340   4/13/2011   4/13/2011        Same Day     DH-3675
# 8    47595  CG-2012-2700  12/22/2012  12/24/2012    Second Class     DH-3675
# 9    43580  RS-2011-8340   4/13/2011   4/13/2011        Same Day     DH-3675
# 10   43461  NI-2014-2000   6/17/2014   6/22/2014  Standard Class     DH-3675
# ...

# %%
df.head() # to display top 5 records
# Out:
#    Row ID      Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0   41520  MA-2013-1850  10/14/2013  10/15/2013     First Class     DH-3675
# 1   47596  CG-2012-2700  12/22/2012  12/24/2012    Second Class     DH-3675
# 2   45892   EG-2014-710    9/3/2014    9/9/2014  Standard Class     DH-3675
# 3   48904  AU-2014-6170   2/17/2014   2/20/2014    Second Class     DH-3675
# 4   42850  TU-2013-3950    4/5/2013    4/6/2013     First Class     DH-3675
#
#    Customer Name      Segment          City        State    ...     \
# 0  Duane Huffman  Home Office  Antananarivo   Analamanga    ...
# 1  Duane Huffman  Home Office      Kinshasa     Kinshasa    ...
# 2  Duane Huffman  Home Office      Damanhur  Al Buhayrah    ...
# 3  Duane Huffman  Home Office        Vienna       Vienna    ...
# 4  Duane Huffman  Home Office      Istanbul     Istanbul    ...
#
#   Sub-Category                         Product Name       Sales Quantity  \
# ...

# %%
df.dtypes
# Out:
# Row ID              int64
# Order_ID           object
# Order_Date         object
# Ship_Date          object
# Ship_Mode          object
# Customer_ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales              object
# Quantity          float64
# Discount          float64
# Profit            float64
# Shipping_Cost     float64
# Order_Priority     object
# Return             object
# Returned            int64
# dtype: object

# %%
df.tail() # dispay bottom 5 records
# Out:
#     Row ID      Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 21   41745  BU-2013-9680    9/9/2013   9/14/2013  Standard Class     DH-3675
# 22   42851  TU-2013-3950    4/5/2013    4/6/2013     First Class     DH-3675
# 23   43579  RS-2011-8340   4/13/2011   4/13/2011        Same Day     DH-3675
# 24   46793  IZ-2014-3850  12/11/2014  12/15/2014  Standard Class     DH-3675
# 25   47999  CG-2012-2700  12/22/2012  12/24/2012    Second Class     DH-3675
#
#     Customer Name      Segment      City          State    ...     \
# 21  Duane Huffman  Home Office     Sofia    Sofiya-Grad    ...
# 22  Duane Huffman  Home Office  Istanbul       Istanbul    ...
# 23    Rodger John  Home Office       Ufa  Bashkortostan    ...
# 24    Rodger John  Home Office   Baghdad        Baghdad    ...
# 25  Duane Huffman  Home Office  Kinshasa       Kinshasa    ...
#
#    Sub-Category                             Product Name   Sales Quantity  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping_Cost', 'Order_Priority', 'Return', 'Returned'],
#       dtype='object')

# %%
df.loc[ df.Profit > 8.64,['Segment','Profit']] # square bracket is meant for subseting the data 
#df.loc[ df.Profit > 8.64] # square bracket is meant for subseting the data 
df.loc[ (df.Profit > 100) & (df.City == 'Kinshasa'),['Segment','Product Name','Profit']] # square bracket is meant for subseting the data
# Out:
#        Segment                         Product Name  Profit
# 1  Home Office  Dania Classic Bookcase, Traditional  176.61

# %%
# label based Search 
# df.loc[rows,columns]
# df.loc[start:end, [list of column names ]]
df.loc[0:4,['Segment','Profit']]
df.loc[[0,2,4,5],['Segment','Profit']]
# Out:
#        Segment   Profit
# 0  Home Office  653.400
# 2  Home Office   58.800
# 4  Home Office  -91.896
# 5  Home Office  -91.896

# %%
# integer based search 
df.iloc[0:4,[7,8]]
df.iloc[[0,2,4,5],[7,8]]
# Out:
#        Segment          City
# 0  Home Office  Antananarivo
# 2  Home Office      Damanhur
# 4  Home Office      Istanbul
# 5  Home Office      Istanbul
